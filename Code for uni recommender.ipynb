# %%
import pandas as pd
import numpy as np
from scipy import sparse
from sklearn.pipeline import make_pipeline
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer, make_column_transformer, make_column_selector
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.pipeline import make_pipeline
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.linear_model import LogisticRegression

from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

# %%
df = pd.read_csv('AO_df_15Feb_withunimajor.csv')

# %%
df = df.rename(columns={'Uni_name': 'uni_name', 'Uni_Jobs': 'job_prospects', 'Uni_Course_lectureres': 'course_lectures', 'Uni_Facilities': 'Facilities', 'Uni_Local_life': 'local_life', 'Uni_Societies_sports': 'societies_and_sports'})

# %%
df.drop(columns = 'Unnamed: 0', inplace=True)

# %%
df_new = df.dropna(inplace=False)

# %%
X = df_new

# %%
y = df_new.pop('uni_name')

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, stratify=y, random_state=2018)

# %%
# Setting the vectorizer just like we would set a model
TfidfVec = TfidfVectorizer(
                                      # sublinear_tf=True,
                                      max_df=0.3,
                                      max_features=10000,
                                      norm='l2'
                                      )

# Fitting the vectorizer on our training data
TfidfVec.fit_transform(df_new['Uni_Major'])
# Out:
# <2397x466 sparse matrix of type '<class 'numpy.float64'>'
# 	with 6978 stored elements in Compressed Sparse Row format>

# %%
preprocessor = ColumnTransformer([('corpus', TfidfVec, 'Uni_Major'), 
                               ('numerical', StandardScaler(), ['job_prospects', 'course_lectures', 'Facilities', 'local_life', 'societies_and_sports'])
                              ], 
                              remainder = 'drop', # treatment for remaining columns
                             sparse_threshold=1) # set threshold for fraction of nonzero entries 
                                                 # to return dense array rather than sparse matrix

# %%
clf = Pipeline(steps=[('preprocessor', preprocessor),
                      ('classifier', LogisticRegression(penalty='none', multi_class='ovr'))])

# %%
clf.fit(X_train, y_train)
# Out:
# /Users/courtneyfroehlig/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /Users/courtneyfroehlig/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
cross_val_score(clf, X_train, y_train, cv=5).mean()
# Out:
# /Users/courtneyfroehlig/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /Users/courtneyfroehlig/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
y_train_pred = clf.predict(X_train)
y_pred = clf.predict(X_test)

# %%
y_train_pred
# Out:
# array(['University of Bristol', 'Imperial College London',
#        'University of Oxford', ..., 'University of Manchester',
#        'Lancaster University', 'University of Nottingham'], dtype=object)

# %%
X_train
# Out:
#                                        Uni_Major  job_prospects  \
# 336                 MSc Education (Open Pathway)            3.0
# 536                       Mathematics BSc (Hons)            3.0
# 1892                Physics (4-year MPhys) MPhys            0.0
# 1902                           Mathematics MMath            0.0
# 2730      Immunology and Pharmacology BSc (Hons)            4.0
# ...                                          ...            ...
# 102                           Biology BSc (Hons)            4.0
# 1490  Business and Management (SocSci) MA (Hons)            0.0
# 2464                     Pharmacology BSc (Hons)            3.0
# 1132            Financial Mathematics BSc (Hons)            0.0
# 1316     Science (Year 0) Foundation Certificate            3.0
#
#       course_lectures  Facilities  local_life  societies_and_sports
# 336               2.0         3.0         4.0                   4.0
# ...

# %%
X_train.iloc[2, :]
# Out:
# Uni_Major               Physics (4-year MPhys) MPhys
# job_prospects                                      0
# course_lectures                                    0
# Facilities                                         4
# local_life                                         4
# societies_and_sports                               0
# Name: 1892, dtype: object

# %%
y
# Out:
# 0                               University of Leeds
# 1                               University of Leeds
# 2                               University of Leeds
# 3                               University of Leeds
# 4                               University of Leeds
#                            ...
# 3227    King's College London, University of London
# 3230    King's College London, University of London
# 3231    King's College London, University of London
# 3233    King's College London, University of London
# 3236    King's College London, University of London
# Name: uni_name, Length: 2397, dtype: object

# %%
X_test
# Out:
#                                             Uni_Major  job_prospects  \
# 2120        Human Geography and Environment BA (Hons)            0.0
# 2453                    Economics and Politics BAECOM            3.0
# 2850                 Chemical Engineering BEng (Hons)            0.0
# 2122  Politics with International Relations BA (Hons)            4.0
# 1871      Marine Biology with Oceanography BSc (Hons)            4.0
# ...                                               ...            ...
# 2626                   Biological Sciences BSc (Hons)            4.0
# 183                              MASt in Astrophysics            4.0
# 2588                     English Literature BA (Hons)            4.0
# 2787                                   Law LLB (Hons)            4.0
# 2180                            Psychology BSc (Hons)            3.0
#
#       course_lectures  Facilities  local_life  societies_and_sports
# 2120              0.0         0.0         0.0                   0.0
# ...

# %%
X_test.iloc[2, :]
# Out:
# Uni_Major               Chemical Engineering BEng (Hons)
# job_prospects                                          0
# course_lectures                                        4
# Facilities                                             4
# local_life                                             3
# societies_and_sports                                   0
# Name: 2850, dtype: object

# %%
dataframe = pd.DataFrame(X_test.iloc[2, :])

# %%
dataframe_reshaped = dataframe.transpose( copy=False)

# %%
clf.predict(dataframe_reshaped)
# Out:
# array(['University of Manchester'], dtype=object)

# %%
X_test
# Out:
#                                             Uni_Major  job_prospects  \
# 2120        Human Geography and Environment BA (Hons)            0.0
# 2453                    Economics and Politics BAECOM            3.0
# 2850                 Chemical Engineering BEng (Hons)            0.0
# 2122  Politics with International Relations BA (Hons)            4.0
# 1871      Marine Biology with Oceanography BSc (Hons)            4.0
# ...                                               ...            ...
# 2626                   Biological Sciences BSc (Hons)            4.0
# 183                              MASt in Astrophysics            4.0
# 2588                     English Literature BA (Hons)            4.0
# 2787                                   Law LLB (Hons)            4.0
# 2180                            Psychology BSc (Hons)            3.0
#
#       course_lectures  Facilities  local_life  societies_and_sports
# 2120              0.0         0.0         0.0                   0.0
# ...
